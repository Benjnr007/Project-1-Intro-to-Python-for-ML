# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding = "latin-1", index_col=1)
df
# Out:
#           Area Code  Item Code           Item  Element Code  \
# Area
# Algeria           4       2501     Population           511
# Algeria           4       2501     Population          5301
# Algeria           4       2901    Grand Total           664
# Algeria           4       2901    Grand Total           674
# Algeria           4       2901    Grand Total           684
# ...             ...        ...            ...           ...
# Zimbabwe        181       2899  Miscellaneous          5142
# Zimbabwe        181       2899  Miscellaneous           645
# Zimbabwe        181       2899  Miscellaneous           664
# Zimbabwe        181       2899  Miscellaneous           674
# Zimbabwe        181       2899  Miscellaneous           684
#
#                                          Element             Unit     Y2014  \
# Area
# Algeria            Total Population - Both sexes     1000 persons  38924.00
# Algeria                 Domestic supply quantity      1000 tonnes      0.00
# ...

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %% [markdown]
# ### Question 1: What is the total number and percentage of missing data in 2014 to 3 decimal places?

# %%
print(df.Y2014.isnull().sum())
print(df.Y2014.isnull().sum()*100/len(df))
# Out:
# 1589
# 2.6073544131401474

# %% [markdown]
# ### Question 2: Perform a groupby operation on ‘Element’.  What year has the highest sum of Stock Variation?

# %%
print(df.groupby("Element")["Y2014"].sum(),df.groupby("Element")["Y2015"].sum(),df.groupby("Element")["Y2016"].sum(),
df.groupby("Element")["Y2017"].sum(),df.groupby("Element")["Y2018"].sum())
# Out:
# Element
# Domestic supply quantity                  1996716.35
# Export Quantity                            150020.64
# Fat supply quantity (g/capita/day)          10225.56
# Feed                                       216927.89
# Food                                      1212332.49
# Food supply (kcal/capita/day)              454257.00
# Food supply quantity (kg/capita/yr)         49650.63
# Import Quantity                            274144.48
# Losses                                     153223.00
# Other uses (non-food)                       78718.13
# Processing                                 282923.00
# Production                                1931287.75
# Protein supply quantity (g/capita/day)      11836.46
# Residuals                                   30149.00
# Seed                                        21922.92
# Stock Variation                             58749.83
# Total Population - Both sexes             1031585.00
# Tourist consumption                           416.00
# ...

# %% [markdown]
# ### Question 4: What is the total Protein supply quantity in Madagascar in 2015?

# %%
pd.set_option("display.max_rows", None)
df.groupby(["Area", "Element"])["Y2015"].sum()
# Out:
# Area                         Element
# Algeria                      Domestic supply quantity                   85972.86
#                              Export Quantity                             1104.62
#                              Fat supply quantity (g/capita/day)           317.40
#                              Feed                                       10308.00
#                              Food                                       61693.49
#                              Food supply (kcal/capita/day)              13512.00
#                              Food supply quantity (kg/capita/yr)         1552.81
#                              Import Quantity                            37841.91
#                              Losses                                      7471.00
#                              Other uses (non-food)                       3483.37
#                              Processing                                  1865.00
# ...

# %% [markdown]
# ### Question 6: Given the following python code, what would the output of the code give?

# %%
my_tuppy = (1,2,5,8)
my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       1 my_tuppy = (1,2,5,8)
# ----> 2 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### Question 7: Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  Which of these Areas had the 7th lowest sum in 2017?

# %%
df.groupby("Area")["Y2017"].sum().sort_values(ascending = False)
# Out:
# Area
# Nigeria                        1483268.23
# Egypt                           866379.92
# South Africa                    517590.54
# Ethiopia                        448683.76
# Morocco                         388495.36
# Ghana                           337599.06
# Algeria                         325644.27
# United Republic of Tanzania     322616.85
# Kenya                           264660.66
# Sudan                           239931.92
# Cameroon                        232030.43
# Angola                          229159.57
# Côte d'Ivoire                   224599.01
# Uganda                          213950.38
# Malawi                          181098.71
# Mozambique                      161407.98
# Mauritania                      156665.46
# Mali                            149928.33
# Madagascar                      131197.73
# Niger                           126707.58
# Benin                           124771.22
# Tunisia                         124167.20
# ...

# %% [markdown]
# ### Question 8: Consider the following list of tuples:

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]

# %%
x = y[1][-1]
x
# Out:
# 8

# %% [markdown]
# ### Question 9: What would be the output for?

# %%
S = [['him', 'sell'], [90, 28, 43]]
S[0][1][1]
# Out:
# 'e'

# %% [markdown]
# ### Question 10: What is the mean and standard deviation across the whole dataset for the year 2017 to 2 decimal places?

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %% [markdown]
# ### Question 12: If you have the following list
#
# lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]
#
# col = [‘Age’,’Nationality’,’Overall’]
#
# How do you create a pandas DataFrame using this list, to look like the table below?

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]
col = ['Age','Nationality','Overall']

# %%
pd.DataFrame(lst, columns=col, index=[1,2,3])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
pd.DataFrame(lst, columns=['Age','Nationality','Overall'], index=[1,2,3])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
pd.DataFrame(lst, columns=col, index=[i for i in range(1,4)])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %% [markdown]
# ### Question 13: Given the following numpy array
#
# array  = ([[94, 89, 63],
#
#              [93, 92, 48],
#
#              [92, 94, 56]])
#
# How would you select  the elements in bold and italics from the array?

# %%
array = ([[94, 89, 63],

         [93, 92, 48],

         [92, 94, 56]])

# %%
array[0]
# Out:
# [94, 89, 63]

# %% [markdown]
# ### Question 14: What is the total number of unique countries in the dataset?

# %%
df.groupby("Area").nunique().sum()
# Out:
# Area Code          49
# Item Code        5430
# Item             5295
# Element Code      803
# Element           803
# Unit              229
# Y2014           14888
# Y2015           14730
# Y2016           14750
# Y2017           14773
# Y2018           14853
# dtype: int64

# %% [markdown]
# ### Question 15: Perform a groupby operation on ‘Element’.  What is the total number of the sum of Processing in 2017?

# %%
df.groupby("Element")["Y2017"].sum()
# Out:
# Element
# Domestic supply quantity                  2088198.10
# Export Quantity                            182338.80
# Fat supply quantity (g/capita/day)          10253.84
# Feed                                       223705.68
# Food                                      1258888.28
# Food supply (kcal/capita/day)              454681.00
# Food supply quantity (kg/capita/yr)         48690.04
# Import Quantity                            294559.09
# Losses                                     160614.00
# Other uses (non-food)                       91645.97
# Processing                                 292836.00
# Production                                2030056.89
# Protein supply quantity (g/capita/day)      11842.45
# Residuals                                   35500.00
# Seed                                        24870.14
# Stock Variation                             54316.91
# Total Population - Both sexes             1112641.00
# Tourist consumption                            91.00
# ...

# %% [markdown]
# ### Question 17: Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  Which of these Areas had the highest sum in 2017?

# %%
df.groupby("Area")["Y2017"].sum().sort_values(ascending=True)
# Out:
# Area
# Sudan (former)                       0.00
# Ethiopia PDR                         0.00
# Comoros                             59.84
# Seychelles                         442.34
# Sao Tome and Principe            12662.63
# Cabo Verde                       14650.74
# Guinea-Bissau                    19102.77
# Lesotho                          21267.96
# Botswana                         22101.30
# Djibouti                         22729.91
# Gambia                           23154.18
# Gabon                            27979.64
# Liberia                          29342.20
# Namibia                          29874.89
# Central African Republic         29937.00
# Congo                            41181.68
# Togo                             49841.88
# Mauritius                        51114.83
# Eswatini                         54343.33
# Sierra Leone                     55311.33
# Chad                             71594.68
# Rwanda                           73663.69
# ...

# %% [markdown]
# ### Question 18: Which year had the least correlation with ‘Element Code’?

# %%
print("2014:", df['Element Code'].corr(df['Y2014']))
print("2015:", df['Element Code'].corr(df['Y2015']))
print("2016:", df['Element Code'].corr(df['Y2016']))
print("2017:", df['Element Code'].corr(df['Y2017']))
print("2018:", df['Element Code'].corr(df['Y2018']))
# Out:
# 2014: 0.024456819495221795
# 2015: 0.02388919930163992
# 2016: 0.023443997584961428
# 2017: 0.02425400776004572
# 2018: 0.02427857195351955

# %% [markdown]
# ### Question 19: Answer the following questions based on the African food production dataset provided by the FAO website already provided
#
# ### What is the total sum of Wine produced in 2015 and 2018 respectively?
#
# ### Hint:
#
# ### Perform a groupby sum aggregation on ‘Item’

# %%
print(df.groupby("Item")["Y2015"].sum())
print(df.groupby("Item")["Y2018"].sum())
# Out:
# Item
# Alcohol, Non-Food                     2180.00
# Alcoholic Beverages                  98783.72
# Animal Products                      11811.73
# Animal fats                         200675.72
# Apples and products                  10559.15
# Aquatic Animals, Others                  9.26
# Aquatic Plants                         631.23
# Aquatic Products, Other                638.42
# Bananas                              55046.76
# Barley and products                  29153.44
# Beans                                20315.77
# Beer                                 42053.67
# Beverages, Alcoholic                  2818.38
# Beverages, Fermented                 47447.92
# Bovine Meat                          22766.42
# Butter, Ghee                          1165.69
# Cassava and products                410235.89
# Cephalopods                            496.95
# Cereals - Excluding Beer            845669.36
# Cereals, Other                       18912.55
# ...
